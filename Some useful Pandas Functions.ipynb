# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# to read / load the dataset 
df=pd.read_csv("test.csv")

# %%
#To check the dataset
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# To check all the columns name
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# dropped a column names "Parch" , inplace= True used to perform the operation permanently 
df.drop(columns=['Parch'] ,inplace=True )

# %%
#Checking new dataset 
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp              Ticket      Fare Cabin Embarked
# ...

# %%
#Provides with the length of the DataFrame. Let’s see an example:
len(df)
# Out:
# 418

# %%
#df.query used to filter data, we can do sinhle nad multiple filtering .
# The below command This will return the rows only where the age  is 22.


df.query("Age==22.0")
# Out:
#      PassengerId  Pclass                                               Name  \
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 63           955       3                       Bradley, Miss. Bridget Delia
# 90           982       3  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...
# 126         1018       3                           Brobeck, Mr. Karl Rudolf
# 147         1039       3                                   Davies, Mr. Evan
# 169         1061       3                       Hellstrom, Miss. Hilda Maria
# 222         1114       2                         Cook, Mrs. (Selena Rogers)
# 246         1138       2              Karnes, Mrs. J Frank (Claire Bennett)
# 279         1171       2                          Oxenham, Mr. Percy Thomas
# 311         1203       3                               Vartanian, Mr. David
# ...

# %%
# This function takes as a parameter the rows and column indices and gives you the subset of the DataFrame accordingly. 
#Here I am taking the first 10 rows of data and index 5th to index 10th columns:
df.iloc[:10,5:10]
# Out:
#    SibSp     Ticket     Fare Cabin Embarked
# 0      0     330911   7.8292   NaN        Q
# 1      1     363272   7.0000   NaN        S
# 2      0     240276   9.6875   NaN        Q
# 3      0     315154   8.6625   NaN        S
# 4      1    3101298  12.2875   NaN        S
# 5      0       7538   9.2250   NaN        S
# 6      0     330972   7.6292   NaN        Q
# 7      1     248738  29.0000   NaN        S
# 8      0       2657   7.2292   NaN        C
# 9      2  A/4 48871  24.1500   NaN        S

# %%
# using df.loc we can call specific rows of any given columns
df.loc[[1,2,3],["Sex","Age","Fare" , "Cabin"]]
# Out:
#       Sex   Age    Fare Cabin
# 1  female  47.0  7.0000   NaN
# 2    male  62.0  9.6875   NaN
# 3    male  27.0  8.6625   NaN

# %%
# to check the data type of whole dataframe 
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#to check data types of a specific colums
df.Age.dtypes
# Out:
# dtype('float64')

# %%
#to call the data type of a given type
df.select_dtypes('float64')
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
# excluded a specific types of data from dataframe
df.select_dtypes(exclude="int64")
# Out:
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# ...

# %%
#inserted a column name team and row values is Bangladesh
df.insert(2,"team" , "Bangladesh")

# %%
df
# Out:
#      PassengerId  Pclass        team  \
# 0            892       3  Bangladesh
# 1            893       3  Bangladesh
# 2            894       2  Bangladesh
# 3            895       3  Bangladesh
# 4            896       3  Bangladesh
# ..           ...     ...         ...
# 413         1305       3  Bangladesh
# 414         1306       1  Bangladesh
# 415         1307       3  Bangladesh
# 416         1308       3  Bangladesh
# 417         1309       3  Bangladesh
#
#                                              Name     Sex   Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                       Myles, Mr. Thomas Francis    male  62.0      0
# 3                                Wirz, Mr. Albert    male  27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                            ...     ...   ...    ...
# ...

# %%
#to get the cumulative sum of any columns we can use this commands
df[["Fare"]].cumsum()
# Out:
#            Fare
# 0        7.8292
# 1       14.8292
# 2       24.5167
# 3       33.1792
# 4       45.4667
# ..          ...
# 413  14709.9793
# 414  14818.8793
# 415  14826.1293
# 416  14834.1793
# 417  14856.5376
#
# [418 rows x 1 columns]

# %%
#When the size of the dataset is too big, we can take a representative 
# sample from it to perform the analysis and predictive modeling.
# That may save  some time. 
df.sample()
# Out:
#      PassengerId  Pclass        team                       Name   Sex   Age  \
# 136         1028       3  Bangladesh  Zakarian, Mr. Mapriededer  male  26.5
#
#      SibSp Ticket   Fare Cabin Embarked
# 136      0   2656  7.225   NaN        C

# %%
# to load the 25% of data we can use 
df.sample(frac= .25)
# Out:
#      PassengerId  Pclass        team  \
# 402         1294       1  Bangladesh
# 183         1075       3  Bangladesh
# 32           924       3  Bangladesh
# 120         1012       2  Bangladesh
# 14           906       1  Bangladesh
# ..           ...     ...         ...
# 401         1293       2  Bangladesh
# 88           980       3  Bangladesh
# 379         1271       3  Bangladesh
# 78           970       2  Bangladesh
# 205         1097       1  Bangladesh
#
#                                                   Name     Sex   Age  SibSp  \
# 402                     Gibson, Miss. Dorothy Winifred  female  22.0      0
# 183                                  Lane, Mr. Patrick    male   NaN      0
# 32            Dean, Mrs. Bertram (Eva Georgetta Light)  female  33.0      1
# 120                               Watt, Miss. Bertha J  female  12.0      0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ...

# %%
# Cheacking out the null values 
df.isnull()
# Out:
#      PassengerId  Pclass   team   Name    Sex    Age  SibSp  Ticket   Fare  \
# 0          False   False  False  False  False  False  False   False  False
# 1          False   False  False  False  False  False  False   False  False
# 2          False   False  False  False  False  False  False   False  False
# 3          False   False  False  False  False  False  False   False  False
# 4          False   False  False  False  False  False  False   False  False
# ..           ...     ...    ...    ...    ...    ...    ...     ...    ...
# 413        False   False  False  False  False   True  False   False  False
# 414        False   False  False  False  False  False  False   False  False
# 415        False   False  False  False  False  False  False   False  False
# 416        False   False  False  False  False   True  False   False  False
# 417        False   False  False  False  False   True  False   False  False
#
#      Cabin  Embarked
# 0     True     False
# 1     True     False
# ...

# %%
#filling up null values of colums Age, using fillna commands. 
df["Age"].fillna(int(df["Age"].mean()) , inplace = True)

# %%
df
# Out:
#      PassengerId  Pclass        team  \
# 0            892       3  Bangladesh
# 1            893       3  Bangladesh
# 2            894       2  Bangladesh
# 3            895       3  Bangladesh
# 4            896       3  Bangladesh
# ..           ...     ...         ...
# 413         1305       3  Bangladesh
# 414         1306       1  Bangladesh
# 415         1307       3  Bangladesh
# 416         1308       3  Bangladesh
# 417         1309       3  Bangladesh
#
#                                              Name     Sex   Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                       Myles, Mr. Thomas Francis    male  62.0      0
# 3                                Wirz, Mr. Albert    male  27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                            ...     ...   ...    ...
# ...

# %%
#Checking out unique value of a specific columns
df["Age"].unique()
# Out:
# array([34.5 , 47.  , 62.  , 27.  , 22.  , 14.  , 30.  , 26.  , 18.  ,
#        21.  , 46.  , 23.  , 63.  , 24.  , 35.  , 45.  , 55.  ,  9.  ,
#        48.  , 50.  , 22.5 , 41.  , 33.  , 18.5 , 25.  , 39.  , 60.  ,
#        36.  , 20.  , 28.  , 10.  , 17.  , 32.  , 13.  , 31.  , 29.  ,
#        28.5 , 32.5 ,  6.  , 67.  , 49.  ,  2.  , 76.  , 43.  , 16.  ,
#         1.  , 12.  , 42.  , 53.  , 26.5 , 40.  , 61.  , 60.5 ,  7.  ,
#        15.  , 54.  , 64.  , 37.  , 34.  , 11.5 ,  8.  ,  0.33, 38.  ,
#        57.  , 40.5 ,  0.92, 19.  , 36.5 ,  0.75,  0.83, 58.  ,  0.17,
#        59.  , 14.5 , 44.  ,  5.  , 51.  ,  3.  , 38.5 ])

# %%
# to check all the unique values of whole dataframe / dataset 
df.nunique()
# Out:
# PassengerId    418
# Pclass           3
# team             1
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
df["Sex"].isin(["Male"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Sex, Length: 418, dtype: bool

# %%
# to replace an specific value 
df.replace(11.5 , 111.5 , inplace= True)

# %%
df["Age"].unique()
# Out:
# array([ 34.5 ,  47.  ,  62.  ,  27.  ,  22.  ,  14.  ,  30.  ,  26.  ,
#         18.  ,  21.  ,  46.  ,  23.  ,  63.  ,  24.  ,  35.  ,  45.  ,
#         55.  ,   9.  ,  48.  ,  50.  ,  22.5 ,  41.  ,  33.  ,  18.5 ,
#         25.  ,  39.  ,  60.  ,  36.  ,  20.  ,  28.  ,  10.  ,  17.  ,
#         32.  ,  13.  ,  31.  ,  29.  ,  28.5 ,  32.5 ,   6.  ,  67.  ,
#         49.  ,   2.  ,  76.  ,  43.  ,  16.  ,   1.  ,  12.  ,  42.  ,
#         53.  ,  26.5 ,  40.  ,  61.  ,  60.5 ,   7.  ,  15.  ,  54.  ,
#         64.  ,  37.  ,  34.  , 111.5 ,   8.  ,   0.33,  38.  ,  57.  ,
#         40.5 ,   0.92,  19.  ,  36.5 ,   0.75,   0.83,  58.  ,   0.17,
#         59.  ,  14.5 ,  44.  ,   5.  ,  51.  ,   3.  ,  38.5 ])

# %%
#to remane a column name we can use df.replace
df.rename(columns={"Age" : "boyos"})
# Out:
#      PassengerId  Pclass        team  \
# 0            892       3  Bangladesh
# 1            893       3  Bangladesh
# 2            894       2  Bangladesh
# 3            895       3  Bangladesh
# 4            896       3  Bangladesh
# ..           ...     ...         ...
# 413         1305       3  Bangladesh
# 414         1306       1  Bangladesh
# 415         1307       3  Bangladesh
# 416         1308       3  Bangladesh
# 417         1309       3  Bangladesh
#
#                                              Name     Sex  boyos  SibSp  \
# 0                                Kelly, Mr. James    male   34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47.0      1
# 2                       Myles, Mr. Thomas Francis    male   62.0      0
# 3                                Wirz, Mr. Albert    male   27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22.0      1
# ..                                            ...     ...    ...    ...
# ...

# %%
# This is the most popular function for data summarizing.
# we can group the data as per a certain variable and find out useful information about those groups.
df.groupby(["Pclass"])['Fare'].sum()
# Out:
# Pclass
# 1    10087.9918
# 2     2264.7957
# 3     2703.7501
# Name: Fare, dtype: float64

# %%
df.groupby(["Pclass"])[['Fare', "Age"]].sum()
# Out:
#               Fare      Age
# Pclass
# 1       10087.9918  4280.00
# 2        2264.7957  2682.42
# 3        2703.7501  5768.08

# %%
#It provides you the number of data in the DataFrame in the specified direction. 
#When the direction is 0, it provides the number of data in the columns:
df.count()
# Out:
# PassengerId    418
# Pclass         418
# team           418
# Name           418
# Sex            418
# Age            418
# SibSp          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
#We can get the value counts of each category using this function.
df["Pclass"].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64
